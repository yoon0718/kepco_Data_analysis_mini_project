# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore", category=Warning)
plt.rcParams['font.family'] = 'Gulim'

# %%
df = pd.read_csv('발전량_지역별.csv',encoding='cp949')

# %%
df = df.astype(int)

# %%
df1=df.sort_values('연도')

# %%
df1.rename(columns = {"연도":"연도_"},inplace=True)

# %%
df1
# Out:
#      연도_       서울        부산       대구        인천      광주      대전        울산  \
# 19  2002  1075409  26625596   121828  22608174       0  213946  10569580
# 18  2003   884477  28266679   118450  21735272     802  182435  10072245
# 17  2004   809665  36169111   134805  27945113   13733  264755  11655794
# 16  2005   902858  35779813   144580  33726808   13166  217146  10581146
# 15  2006  1249721  36526608   137565  39145681   17419  216837  10424658
# 14  2007  1599194  35738820   131201  44781497   11478  234641  11182401
# 13  2008  1165462  37657231   113907  49316491    7701  203207   8103303
# 12  2009   845145  36058741   123589  54308250    5457  187958   8465778
# 11  2010  1546123  40885522   146950  62767222   37852  195644  10149653
# 10  2011  1384406  39131349   197978  68952842   37369  156053  10749542
# 9   2012  1981199  35685485   264243  76386995  138121  239222  14609288
# 8   2013  2184346  38074350   302056  80861254  581864  231663  14048956
# ...

# %%
df1.to_csv('c:/work/project/power generation.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df1.to_csv('c:/work/project/power generation.csv',index=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:3720, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3709 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3711 formatter = DataFrameFormatter(
#    3712     frame=df,
# ...

# %%
list_col=list(df1.columns)

# %%
list_col[1:]
# Out:
# ['서울',
#  '부산',
#  '대구',
#  '인천',
#  '광주',
#  '대전',
#  '울산',
#  '세종',
#  '경기',
#  '강원',
#  '충북',
#  '충남',
#  '전북',
#  '전남',
#  '경북',
#  '경남',
#  '제주']

# %%
years = df1['연도_'].unique()

# %%
df1['연도_']
# Out:
# 19    2002
# 18    2003
# 17    2004
# 16    2005
# 15    2006
# 14    2007
# 13    2008
# 12    2009
# 11    2010
# 10    2011
# 9     2012
# 8     2013
# 7     2014
# 6     2015
# 5     2016
# 4     2017
# 3     2018
# 2     2019
# 1     2020
# 0     2021
# Name: 연도_, dtype: int32

# %%
# # 예시 데이터 프레임 (df1)과 연도 목록 (years) 생성
# years = df1['연도'].unique()

# # 그래프 크기 설정
# plt.figure(figsize=(20, 20))

# # 각 도시별로 반복하며 막대 그래프 생성
# for city in list_col[1:]:
#     bottom = 0  # 각 도시의 시작 높이 초기화
#     for i in years:
#         city_data = df1[df1['연도'] == year][city]  # 해당 연도의 도시 데이터 가져오기
#         plt.bar(i, city_data, bottom=bottom, label=city if bottom == 0 else "")
#         bottom += city_data
# # 범례 추가
# plt.legend()

# # 그래프 표시
# plt.show()

# %%
# list_col=list(df1.columns)
# list_years=list(years)
# for city in list_col[1:]:
#     bottom=0
#     for year in list_years:
#         city_data= df1[df1['연도']==year][city]
#         plt.bar(year, city_data, bottom=bottom if bottom ==0 else "")
#         bottom= bottom+city_data

# %%
plt.figure(figsize=(20,20))
plt.bar(df1['연도_'],df1['서울'])
plt.bar(df1['연도_'],df1['부산'],bottom=df1['서울'])
plt.bar(df1['연도_'],df1['대구'],bottom=df1['서울']+df1['부산'])
plt.bar(df1['연도_'],df1['인천'],bottom=df1['서울']+df1['부산']+df1['대구'])
plt.bar(df1['연도_'],df1['광주'],bottom=df1['서울']+df1['부산']+df1['대구']+df1['인천'])
plt.bar(df1['연도_'],df1['대전'],bottom=df1['서울']+df1['부산']+df1['대구']+df1['인천']+df1['광주'])
plt.bar(df1['연도_'],df1['울산'],bottom=df1['서울']+df1['부산']+df1['대구']+df1['인천']+df1['광주']+df1['대전'])
plt.bar(df1['연도_'],df1['세종'],bottom=df1['서울']+df1['부산']+df1['대구']+df1['인천']+df1['광주']+df1['대전']+df1['울산'])
plt.bar(df1['연도_'],df1['경기'],bottom=df1['서울']+df1['부산']+df1['대구']+df1['인천']+df1['광주']+df1['대전']+df1['울산']+df1['세종'])
plt.bar(df1['연도_'],df1['강원'],bottom=df1['서울']+df1['부산']+df1['대구']+df1['인천']+df1['광주']+df1['대전']+df1['울산']+df1['세종']+df1['경기'])
plt.bar(df1['연도_'],df1['충북'],bottom=df1['서울']+df1['부산']+df1['대구']+df1['인천']+df1['광주']+df1['대전']+df1['울산']+df1['세종']+df1['경기']+df1['강원'])
plt.bar(df1['연도_'],df1['충남'],bottom=df1['서울']+df1['부산']+df1['대구']+df1['인천']+df1['광주']+df1['대전']+df1['울산']+df1['세종']+df1['경기']+df1['강원']+df1['충북'])
plt.bar(df1['연도_'],df1['전북'],bottom=df1['서울']+df1['부산']+df1['대구']+df1['인천']+df1['광주']+df1['대전']+df1['울산']+df1['세종']+df1['경기']+df1['강원']+df1['충북']+df1['충남'])
plt.bar(df1['연도_'],df1['전남'],bottom=df1['서울']+df1['부산']+df1['대구']+df1['인천']+df1['광주']+df1['대전']+df1['울산']+df1['세종']+df1['경기']+df1['강원']+df1['충북']+df1['충남']+df1['전북'])
plt.bar(df1['연도_'],df1['경북'],bottom=df1['서울']+df1['부산']+df1['대구']+df1['인천']+df1['광주']+df1['대전']+df1['울산']+df1['세종']+df1['경기']+df1['강원']+df1['충북']+df1['충남']+df1['전북']+df1['전남'])
plt.bar(df1['연도_'],df1['경남'],bottom=df1['서울']+df1['부산']+df1['대구']+df1['인천']+df1['광주']+df1['대전']+df1['울산']+df1['세종']+df1['경기']+df1['강원']+df1['충북']+df1['충남']+df1['전북']+df1['전남']+df1['경북'])
plt.bar(df1['연도_'],df1['제주'],bottom=df1['서울']+df1['부산']+df1['대구']+df1['인천']+df1['광주']+df1['대전']+df1['울산']+df1['세종']+df1['경기']+df1['강원']+df1['충북']+df1['충남']+df1['전북']+df1['전남']+df1['경북']+df1['경남'])
plt.title('지역별 총 발전량',fontsize='20')
plt.xlabel('연도',fontsize='20')
plt.ylabel('총 발전량',fontsize='20')
# 그래프에 연도 레이블 추가
plt.xticks(df1['연도_'], fontsize='20')
plt.ticklabel_format(axis='y',useOffset=False, style='plain')
# 범례 추가
plt.legend(list_col[1:],loc='upper left', fontsize='15')
plt.show()

# %%
year=df.set_index('연도')

# %%
year
# Out:
#            서울        부산       대구        인천      광주      대전        울산       세종  \
# 연도
# 2021  5343889  40353946  2811756  60506261  644018  182180  31503575  3776643
# 2020  5122176  40647380  2568644  57135627  609551  167834  29808674  3552567
# 2019  1846891  37527898  2877895  60052894  562074  167975  29016048  2463629
# 2018   640739  38495982  2649458  62929390  514494  183668  20588807  3718198
# 2017   841569  26550923  2673615  62555723  480426  184668  22677064  3052432
# 2016   874131  51006660  3105758  65939273  429418  186769  13583162  2840978
# 2015   768860  47218627  2816369  68377707  383433  168642   9065208     8660
# 2014   799391  37424885   513395  73425270  399737  151727   9961740        0
# 2013  2184346  38074350   302056  80861254  581864  231663  14048956        0
# 2012  1981199  35685485   264243  76386995  138121  239222  14609288        0
# 2011  1384406  39131349   197978  68952842   37369  156053  10749542        0
# ...

# %%
yea=list(year.index)

# %%
yea
# Out:
# [2021,
#  2020,
#  2019,
#  2018,
#  2017,
#  2016,
#  2015,
#  2014,
#  2013,
#  2012,
#  2011,
#  2010,
#  2009,
#  2008,
#  2007,
#  2006,
#  2005,
#  2004,
#  2003,
#  2002]

# %%
list(year.columns)
# Out:
# ['서울',
#  '부산',
#  '대구',
#  '인천',
#  '광주',
#  '대전',
#  '울산',
#  '세종',
#  '경기',
#  '강원',
#  '충북',
#  '충남',
#  '전북',
#  '전남',
#  '경북',
#  '경남',
#  '제주']

# %%
seo=year['서울'].tolist()

# %%
seo[1]
# Out:
# 5122176

# %%
fig, ax = plt.subplots(figsize=(20,20))
for i in list(year.columns):
    ax.plot(yea,year[i],label=i,linewidth=3)
ax.set_title('연도별 총발전량',fontsize='20')
ax.set_xlabel('연도',fontsize='20')
ax.set_ylabel('총발전량',fontsize='20')
ax.legend(fontsize='15')
fig.show
# ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=False))
# Out:
# <bound method Figure.show of <Figure size 2000x2000 with 1 Axes>>

# %%
year.plot(kind='bar',figsize=(15,15))
# Out:
# <Axes: xlabel='연도'>

# %%
pl = pd.read_csv('전력손실량.csv',encoding='cp949')

# %%
pl
# Out:
#         연도    송전단 전력량(A)          송변전손실   Unnamed: 3   Unnamed: 4  \
# 0      NaN           NaN         배전량(B)     손실량(A-B)       손실률(%)
# 1   2021.0  5.496238e+08  540972704.668  8651078.637        1.574
# 2   2020.0  5.258508e+08      517571775      8278987         1.57
# 3   2019.0  5.361978e+08  527752245.289  8445564.198        1.575
# 4   2018.0  5.432316e+08    534612230.2  8619365.574  1.586683404
# ..     ...           ...            ...          ...          ...
# 57  1965.0  3.049563e+06        2702991       346572        11.37
# 58  1964.0  2.551965e+06        2277420       274545        10.76
# 59  1963.0  2.133558e+06        1901285       232273        10.89
# 60  1962.0  1.890865e+06        1705277       185587         9.82
# 61  1961.0  1.683584e+06        1495254       188330        11.19
#
#              배전손실    Unnamed: 6   Unnamed: 7          종합손실   Unnamed: 9
# 0          판매량(C)      손실량(B-C)       손실률(%)      손실량(A-C)       손실률(%)
# ...

# %%
pl.rename(columns={'송변전손실':'송변전손실_배전량(B)'},inplace=True)

# %%
pl.rename(columns={'Unnamed: 3':'송변전손실_손실량(A-B)','Unnamed: 4':'송변전손실_손실률(%)','배전손실':'배전손실_판매량(C)'},inplace=True)

# %%
pl.rename(columns={'Unnamed: 6':'손실량_(B-C)','Unnamed: 7':'손실률(%)','종합손실':'종합손실_손실량(A-C)','Unnamed: 9':'종합손실률(%)'},inplace=True)

# %%
pl
# Out:
#         연도    송전단 전력량(A)   송변전손실_배전량(B) 송변전손실_손실량(A-B) 송변전손실_손실률(%)  \
# 0      NaN           NaN         배전량(B)       손실량(A-B)       손실률(%)
# 1   2021.0  5.496238e+08  540972704.668    8651078.637        1.574
# 2   2020.0  5.258508e+08      517571775        8278987         1.57
# 3   2019.0  5.361978e+08  527752245.289    8445564.198        1.575
# 4   2018.0  5.432316e+08    534612230.2    8619365.574  1.586683404
# ..     ...           ...            ...            ...          ...
# 57  1965.0  3.049563e+06        2702991         346572        11.37
# 58  1964.0  2.551965e+06        2277420         274545        10.76
# 59  1963.0  2.133558e+06        1901285         232273        10.89
# 60  1962.0  1.890865e+06        1705277         185587         9.82
# 61  1961.0  1.683584e+06        1495254         188330        11.19
#
#       배전손실_판매량(C)     손실량_(B-C)       손실률(%) 종합손실_손실량(A-C)     종합손실률(%)
# 0          판매량(C)      손실량(B-C)       손실률(%)      손실량(A-C)       손실률(%)
# ...

# %%
pl1=pl.iloc[1:]

# %%
pl1
# Out:
#         연도    송전단 전력량(A)   송변전손실_배전량(B) 송변전손실_손실량(A-B) 송변전손실_손실률(%)  \
# 1   2021.0  5.496238e+08  540972704.668    8651078.637        1.574
# 2   2020.0  5.258508e+08      517571775        8278987         1.57
# 3   2019.0  5.361978e+08  527752245.289    8445564.198        1.575
# 4   2018.0  5.432316e+08    534612230.2    8619365.574  1.586683404
# 5   2017.0  5.257108e+08      517358021        8352731         1.59
# ..     ...           ...            ...            ...          ...
# 57  1965.0  3.049563e+06        2702991         346572        11.37
# 58  1964.0  2.551965e+06        2277420         274545        10.76
# 59  1963.0  2.133558e+06        1901285         232273        10.89
# 60  1962.0  1.890865e+06        1705277         185587         9.82
# 61  1961.0  1.683584e+06        1495254         188330        11.19
#
#       배전손실_판매량(C)     손실량_(B-C)       손실률(%) 종합손실_손실량(A-C)     종합손실률(%)
# 1   530199565.459  10773139.209        1.991  19424217.846        3.534
# ...

# %%
pl1.plot.scatter('연도','송전단 전력량(A)',alpha=.5)
# Out:
# <Axes: xlabel='연도', ylabel='송전단 전력량(A)'>

# %%
pl1.columns[1:]
# Out:
# Index(['송전단 전력량(A)', '송변전손실_배전량(B)', '송변전손실_손실량(A-B)', '송변전손실_손실률(%)',
#        '배전손실_판매량(C)', '손실량_(B-C)', '손실률(%)', '종합손실_손실량(A-C)', '종합손실률(%)'],
#       dtype='object')

# %%
list(pl1['연도'])
# Out:
# [2021.0,
#  2020.0,
#  2019.0,
#  2018.0,
#  2017.0,
#  2016.0,
#  2015.0,
#  2014.0,
#  2013.0,
#  2012.0,
#  2011.0,
#  2010.0,
#  2009.0,
#  2008.0,
#  2007.0,
#  2006.0,
#  2005.0,
#  2004.0,
#  2003.0,
#  2002.0,
#  2001.0,
#  2000.0,
#  1999.0,
#  1998.0,
#  1997.0,
#  1996.0,
#  1995.0,
#  1994.0,
#  1993.0,
#  1992.0,
#  1991.0,
#  1990.0,
#  1989.0,
#  1988.0,
#  1987.0,
#  1986.0,
#  1985.0,
#  1984.0,
#  1983.0,
#  1982.0,
#  1981.0,
#  1980.0,
#  1979.0,
#  1978.0,
#  1977.0,
#  1976.0,
#  1975.0,
#  1974.0,
#  1973.0,
#  1972.0,
#  1971.0,
#  1970.0,
#  1969.0,
#  1968.0,
#  1967.0,
#  1966.0,
#  1965.0,
#  1964.0,
#  1963.0,
#  1962.0,
#  1961.0]

# %%
list(pl1.columns[1:])
# Out:
# ['송전단 전력량(A)',
#  '송변전손실_배전량(B)',
#  '송변전손실_손실량(A-B)',
#  '송변전손실_손실률(%)',
#  '배전손실_판매량(C)',
#  '손실량_(B-C)',
#  '손실률(%)',
#  '종합손실_손실량(A-C)',
#  '종합손실률(%)']

# %%
pl1['송전단 전력량(A)']
# Out:
# 1     5.496238e+08
# 2     5.258508e+08
# 3     5.361978e+08
# 4     5.432316e+08
# 5     5.257108e+08
#           ...
# 57    3.049563e+06
# 58    2.551965e+06
# 59    2.133558e+06
# 60    1.890865e+06
# 61    1.683584e+06
# Name: 송전단 전력량(A), Length: 61, dtype: float64

# %%
pl1['연도']
# Out:
# 1     2021.0
# 2     2020.0
# 3     2019.0
# 4     2018.0
# 5     2017.0
#        ...
# 57    1965.0
# 58    1964.0
# 59    1963.0
# 60    1962.0
# 61    1961.0
# Name: 연도, Length: 61, dtype: float64

# %%
pl1
# Out:
#         연도    송전단 전력량(A)   송변전손실_배전량(B) 송변전손실_손실량(A-B) 송변전손실_손실률(%)  \
# 1   2021.0  5.496238e+08  540972704.668    8651078.637        1.574
# 2   2020.0  5.258508e+08      517571775        8278987         1.57
# 3   2019.0  5.361978e+08  527752245.289    8445564.198        1.575
# 4   2018.0  5.432316e+08    534612230.2    8619365.574  1.586683404
# 5   2017.0  5.257108e+08      517358021        8352731         1.59
# ..     ...           ...            ...            ...          ...
# 57  1965.0  3.049563e+06        2702991         346572        11.37
# 58  1964.0  2.551965e+06        2277420         274545        10.76
# 59  1963.0  2.133558e+06        1901285         232273        10.89
# 60  1962.0  1.890865e+06        1705277         185587         9.82
# 61  1961.0  1.683584e+06        1495254         188330        11.19
#
#       배전손실_판매량(C)     손실량_(B-C)       손실률(%) 종합손실_손실량(A-C)     종합손실률(%)
# 1   530199565.459  10773139.209        1.991  19424217.846        3.534
# ...

# %%
pl1=pl1.astype(float)

# %%
pl1.연도=pl1.연도.astype(int)

# %%
pl2=pl1.set_index('연도')

# %%
pl2
# Out:
#         송전단 전력량(A)  송변전손실_배전량(B)  송변전손실_손실량(A-B)  송변전손실_손실률(%)   배전손실_판매량(C)  \
# 연도
# 2021  5.496238e+08  5.409727e+08     8651078.637      1.574000  5.301996e+08
# 2020  5.258508e+08  5.175718e+08     8278987.000      1.570000  5.072408e+08
# 2019  5.361978e+08  5.277522e+08     8445564.198      1.575000  5.171973e+08
# 2018  5.432316e+08  5.346122e+08     8619365.574      1.586683  5.238722e+08
# 2017  5.257108e+08  5.173580e+08     8352731.000      1.590000  5.069207e+08
# ...            ...           ...             ...           ...           ...
# 1965  3.049563e+06  2.702991e+06      346572.000     11.370000  2.463687e+06
# 1964  2.551965e+06  2.277420e+06      274545.000     10.760000  2.043413e+06
# 1963  2.133558e+06  1.901285e+06      232273.000     10.890000  1.695620e+06
# 1962  1.890865e+06  1.705277e+06      185587.000      9.820000  1.470100e+06
# 1961  1.683584e+06  1.495254e+06      188330.000     11.190000  1.189386e+06
#
# ...

# %%
pl2=pl2.sort_values('연도')

# %%
pl2
# Out:
#         송전단 전력량(A)  송변전손실_배전량(B)  송변전손실_손실량(A-B)  송변전손실_손실률(%)   배전손실_판매량(C)  \
# 연도
# 1961  1.683584e+06  1.495254e+06      188330.000     11.190000  1.189386e+06
# 1962  1.890865e+06  1.705277e+06      185587.000      9.820000  1.470100e+06
# 1963  2.133558e+06  1.901285e+06      232273.000     10.890000  1.695620e+06
# 1964  2.551965e+06  2.277420e+06      274545.000     10.760000  2.043413e+06
# 1965  3.049563e+06  2.702991e+06      346572.000     11.370000  2.463687e+06
# ...            ...           ...             ...           ...           ...
# 2017  5.257108e+08  5.173580e+08     8352731.000      1.590000  5.069207e+08
# 2018  5.432316e+08  5.346122e+08     8619365.574      1.586683  5.238722e+08
# 2019  5.361978e+08  5.277522e+08     8445564.198      1.575000  5.171973e+08
# 2020  5.258508e+08  5.175718e+08     8278987.000      1.570000  5.072408e+08
# 2021  5.496238e+08  5.409727e+08     8651078.637      1.574000  5.301996e+08
#
# ...

# %%
plt.figure(figsize=(10,10))
plt.plot(pl2.index,
         pl2['송전단 전력량(A)'],
         color ='green',
         linestyle = ':',
         marker = '^'
        )
plt.ticklabel_format(axis='y',useOffset=False, style='plain')
plt.title('연도별 송전단 전력량')
plt.xlabel('연도')
plt.ylabel('송전단 전력량')
plt.xticks(range(1960,2023,10))
# Out:
# ([<matplotlib.axis.XTick at 0x2181d268a50>,
# ...
#  [Text(1960, 0, '1960'),
#   Text(1970, 0, '1970'),
#   Text(1980, 0, '1980'),
#   Text(1990, 0, '1990'),
#   Text(2000, 0, '2000'),
#   Text(2010, 0, '2010'),
#   Text(2020, 0, '2020')])

# %%
pl2.index[:30]
# Out:
# Int64Index([1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#             1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982,
#             1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990],
#            dtype='int64', name='연도')

# %%
pl2['송전단 전력량(A)'][0:2]
# Out:
# 연도
# 1961    1683584.0
# 1962    1890865.0
# Name: 송전단 전력량(A), dtype: float64

# %%
plt.figure(figsize=(15,10))
plt.bar(pl2.index[:30],pl2['송전단 전력량(A)'][:30],color='r',align='edge',width=0.2,label='송전단 전력량(A)')
plt.bar(pl2.index[:30]+0.2,pl2['송변전손실_배전량(B)'][:30],color='g',align='edge',width=0.2,label='송변전 배전량(B)')
plt.bar(pl2.index[:30]-0.2,pl2['송변전손실_손실량(A-B)'][:30],color='b',align='edge',width=0.2,label='손실량(A-B)')
plt.xticks(pl2.index[:30])
plt.ticklabel_format(axis='y',useOffset=False, style='plain')
plt.xlabel('연도')
plt.ylabel('전력량')
plt.legend(loc='center')
plt.title('송전단전력량,배전량,손실량')
# Out:
# Text(0.5, 1.0, '송전단전력량,배전량,손실량')

# %%
plt.figure(figsize=(15,10))
plt.bar(pl2.index[30:],pl2['송전단 전력량(A)'][30:],color='r',align='edge',width=0.2,label='송전단 전력량(A)')
plt.bar(pl2.index[30:]+0.2,pl2['송변전손실_배전량(B)'][30:],color='g',align='edge',width=0.2,label='송변전 배전량(B)')
plt.bar(pl2.index[30:]-0.2,pl2['송변전손실_손실량(A-B)'][30:],color='b',align='edge',width=0.2,label='손실량(A-B)')
plt.xticks(pl2.index[30:])
plt.ticklabel_format(axis='y',useOffset=False, style='plain')
plt.xlabel('연도',fontsize='15')
plt.ylabel('전력량',fontsize='15')
plt.legend()
plt.title('송전단전력량,배전량,손실량')
# Out:
# Text(0.5, 1.0, '송전단전력량,배전량,손실량')

# %%
plt.figure(figsize=(15,10))
plt.bar(pl2.index[:30],pl2['송변전손실_배전량(B)'][:30],color='c',align='edge',width=0.2,label='송변전 배전량(B)')
plt.bar(pl2.index[:30]+0.2,pl2['배전손실_판매량(C)'][:30],color='m',align='edge',width=0.2,label='배전 판매량(C)')
plt.bar(pl2.index[:30]-0.2,pl2['손실량_(B-C)'][:30],color='y',align='edge',width=0.2,label='손실량(B-C)')
plt.xticks(pl2.index[:30])
plt.ticklabel_format(axis='y',useOffset=False, style='plain')
plt.xlabel('연도')
plt.ylabel('전력량')
plt.legend(loc='center')
plt.title('배전량,판매량,손실량')
# Out:
# Text(0.5, 1.0, '배전량,판매량,손실량')

# %%
plt.figure(figsize=(15,10))
plt.bar(pl2.index[30:],pl2['송변전손실_배전량(B)'][30:],color='c',align='edge',width=0.2,label='송변전 배전량(B)')
plt.bar(pl2.index[30:]+0.2,pl2['배전손실_판매량(C)'][30:],color='m',align='edge',width=0.2,label='배전 판매량(C)')
plt.bar(pl2.index[30:]-0.2,pl2['손실량_(B-C)'][30:],color='y',align='edge',width=0.2,label='손실량(B-C)')
plt.xticks(pl2.index[30:])
plt.ticklabel_format(axis='y',useOffset=False, style='plain')
plt.xlabel('연도')
plt.ylabel('전력량')
plt.legend()
plt.title('배전량,판매량,손실량')
# Out:
# Text(0.5, 1.0, '배전량,판매량,손실량')

# %%
plt.figure(figsize=(15,10))
plt.bar(pl2.index[:30],pl2['송전단 전력량(A)'][:30],color='r',align='edge',width=0.2,label='송전단 전력량(A)')
plt.bar(pl2.index[:30]+0.2,pl2['종합손실_손실량(A-C)'][:30],color='g',align='edge',width=0.2,label='종합손실량(A-C)')
plt.xticks(pl2.index[:30])
plt.ticklabel_format(axis='y',useOffset=False, style='plain')
plt.xlabel('연도')
plt.ylabel('전력량')

plt.legend(loc='center')
plt.title('송전단전력량,종합_손실량')
# Out:
# Text(0.5, 1.0, '송전단전력량,종합_손실량')

# %%
plt.figure(figsize=(15,10))
plt.bar(pl2.index[30:],pl2['송전단 전력량(A)'][30:],color='r',align='edge',width=0.2,label='송전단 전력량(A)')
plt.bar(pl2.index[30:]+0.2,pl2['종합손실_손실량(A-C)'][30:],color='g',align='edge',width=0.2,label='종합손실량(A-C)')
plt.xticks(pl2.index[30:])
plt.ticklabel_format(axis='y',useOffset=False, style='plain')
plt.xlabel('연도')
plt.ylabel('전력량')

plt.legend(loc='center')
plt.title('송전단전력량,종합_손실량')
# Out:
# Text(0.5, 1.0, '송전단전력량,종합_손실량')

# %%
pl3=pl2.reset_index()

# %%
pl3
# Out:
#       연도    송전단 전력량(A)  송변전손실_배전량(B)  송변전손실_손실량(A-B)  송변전손실_손실률(%)  \
# 0   1961  1.683584e+06  1.495254e+06      188330.000     11.190000
# 1   1962  1.890865e+06  1.705277e+06      185587.000      9.820000
# 2   1963  2.133558e+06  1.901285e+06      232273.000     10.890000
# 3   1964  2.551965e+06  2.277420e+06      274545.000     10.760000
# 4   1965  3.049563e+06  2.702991e+06      346572.000     11.370000
# ..   ...           ...           ...             ...           ...
# 56  2017  5.257108e+08  5.173580e+08     8352731.000      1.590000
# 57  2018  5.432316e+08  5.346122e+08     8619365.574      1.586683
# 58  2019  5.361978e+08  5.277522e+08     8445564.198      1.575000
# 59  2020  5.258508e+08  5.175718e+08     8278987.000      1.570000
# 60  2021  5.496238e+08  5.409727e+08     8651078.637      1.574000
#
#      배전손실_판매량(C)     손실량_(B-C)     손실률(%)  종합손실_손실량(A-C)   종합손실률(%)
# 0   1.189386e+06  3.058680e+05  18.170000   4.941980e+05  29.350000
# ...

# %%
pl3.rename(columns={"송전단 전력량(A)":"송전단_전력량(A)"},inplace=True)

# %%
pl3.rename(columns={"송변전손실_손실률(%)":"송변전손실_손실률","손실률(%)":"손실률","종합손실률(%)":"종합손실률"},inplace=True)

# %%
pl3.rename(columns={"송전단_전력량(A)":"송전단_전력량A","송변전손실_배전량(B)":"송변전손실_배전량B","송변전손실_손실량(A-B)":"송변전손실_손실량_A_B"},inplace=True)

# %%
pl3.rename(columns={"배전손실_판매량(C)":"배전손실_판매량C","손실량_(B-C)":"손실량_B_C","종합손실_손실량(A-C)":"종합손실_손실량_A_C"},inplace=True)

# %%
pl3
# Out:
#       연도      송전단_전력량A    송변전손실_배전량B  송변전손실_손실량_A_B  송변전손실_손실률     배전손실_판매량C  \
# 0   1961  1.683584e+06  1.495254e+06     188330.000  11.190000  1.189386e+06
# 1   1962  1.890865e+06  1.705277e+06     185587.000   9.820000  1.470100e+06
# 2   1963  2.133558e+06  1.901285e+06     232273.000  10.890000  1.695620e+06
# 3   1964  2.551965e+06  2.277420e+06     274545.000  10.760000  2.043413e+06
# 4   1965  3.049563e+06  2.702991e+06     346572.000  11.370000  2.463687e+06
# ..   ...           ...           ...            ...        ...           ...
# 56  2017  5.257108e+08  5.173580e+08    8352731.000   1.590000  5.069207e+08
# 57  2018  5.432316e+08  5.346122e+08    8619365.574   1.586683  5.238722e+08
# 58  2019  5.361978e+08  5.277522e+08    8445564.198   1.575000  5.171973e+08
# 59  2020  5.258508e+08  5.175718e+08    8278987.000   1.570000  5.072408e+08
# 60  2021  5.496238e+08  5.409727e+08    8651078.637   1.574000  5.301996e+08
#
# ...

# %%
table1=pl3.loc[:,(pl3.columns=='연도')|(pl3.columns=='송전단_전력량A')|(pl3.columns=='배전손실_판매량C')|(pl3.columns=='종합손실_손실량_A_C')|(pl3.columns=='종합손실률')]

# %%
table2 = pl3.loc[:,(pl3.columns=='송전단_전력량A')|(pl3.columns=='송변전손실_배전량B')|(pl3.columns=='송변전손실_손실량_A_B')|(pl3.columns=='송변전손실_손실률')]

# %%
table3 = pl3.loc[:,(pl3.columns=='배전손실_판매량C')|(pl3.columns=='송변전손실_배전량B')|(pl3.columns=='손실량_B_C')|(pl3.columns=='손실률')]

# %%
table1
# Out:
#       연도      송전단_전력량A     배전손실_판매량C  종합손실_손실량_A_C      종합손실률
# 0   1961  1.683584e+06  1.189386e+06  4.941980e+05  29.350000
# 1   1962  1.890865e+06  1.470100e+06  4.207640e+05  22.350000
# 2   1963  2.133558e+06  1.695620e+06  4.379380e+05  20.530000
# 3   1964  2.551965e+06  2.043413e+06  5.085220e+05  19.930000
# 4   1965  3.049563e+06  2.463687e+06  5.858750e+05  19.210000
# ..   ...           ...           ...           ...        ...
# 56  2017  5.257108e+08  5.069207e+08  1.879010e+07   3.570000
# 57  2018  5.432316e+08  5.238722e+08  1.935935e+07   3.563739
# 58  2019  5.361978e+08  5.171973e+08  1.900047e+07   3.544000
# 59  2020  5.258508e+08  5.072408e+08  1.860997e+07   3.540000
# 60  2021  5.496238e+08  5.301996e+08  1.942422e+07   3.534000
#
# [61 rows x 5 columns]

# %%
table2
# Out:
#         송전단_전력량A    송변전손실_배전량B  송변전손실_손실량_A_B  송변전손실_손실률
# 0   1.683584e+06  1.495254e+06     188330.000  11.190000
# 1   1.890865e+06  1.705277e+06     185587.000   9.820000
# 2   2.133558e+06  1.901285e+06     232273.000  10.890000
# 3   2.551965e+06  2.277420e+06     274545.000  10.760000
# 4   3.049563e+06  2.702991e+06     346572.000  11.370000
# ..           ...           ...            ...        ...
# 56  5.257108e+08  5.173580e+08    8352731.000   1.590000
# 57  5.432316e+08  5.346122e+08    8619365.574   1.586683
# 58  5.361978e+08  5.277522e+08    8445564.198   1.575000
# 59  5.258508e+08  5.175718e+08    8278987.000   1.570000
# 60  5.496238e+08  5.409727e+08    8651078.637   1.574000
#
# [61 rows x 4 columns]

# %%
table3
# Out:
#       송변전손실_배전량B     배전손실_판매량C       손실량_B_C        손실률
# 0   1.495254e+06  1.189386e+06  3.058680e+05  18.170000
# 1   1.705277e+06  1.470100e+06  2.351770e+05  12.440000
# 2   1.901285e+06  1.695620e+06  2.056650e+05   9.640000
# 3   2.277420e+06  2.043413e+06  2.340070e+05   9.170000
# 4   2.702991e+06  2.463687e+06  2.393030e+05   7.850000
# ..           ...           ...           ...        ...
# 56  5.173580e+08  5.069207e+08  1.043737e+07   2.020000
# 57  5.346122e+08  5.238722e+08  1.073999e+07   2.008931
# 58  5.277522e+08  5.171973e+08  1.055491e+07   2.000000
# 59  5.175718e+08  5.072408e+08  1.033098e+07   2.000000
# 60  5.409727e+08  5.301996e+08  1.077314e+07   1.991000
#
# [61 rows x 4 columns]
